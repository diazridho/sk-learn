# %% [markdown]
# ![Screenshot 2026-01-05 142632.png](<attachment:Screenshot 2026-01-05 142632.png>)

# %%
# Gradient Descent: algoritma optimasi untuk menurunkan cost function 
# learning rate: menentukan seberapa besar langkah(perubahan m dan b) yang diambil setiap iterasi
# Output dari algoritma ini adalah menemukan fit line terbaik

# %%
# Alur algoritma: 

# 1. Memberikan nilai sembarangan untuk m dan b
# 2. Menghitung cost function (MSE)
# 3. Menghitung turunan parsial dari cost function terhadap m dan b
# 4. Memperbarui nilai m dan b menggunakan learning rate dan turunan parsial
# 5. Mengulangi langkah 2-4 hingga konvergen atau mencapai iterasi maksimum
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1579: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1579: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_stochastic_gradient.py:1579: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# ...
