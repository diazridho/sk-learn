# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Linear Regression
# algoritma yang memprediksi nilai y berdasarkan nilai x dengan mencari garis terbaik yang sesuai dengan data yang ada
# mx+b

# %%
koefisien :
# aspek penting yaitu m: slope (gradient) and b: y-intercept

residual/error:
# selisih y aktual dengan y prediksi

cost function:
# mean squared error (MSE), semakin kecil nilai MSE, semakin baik model

regularization:
# teknik untuk mencegah overfitting dengan memberikan nilai koefisien 0 pada fitur yang tidak penting (contoh, cat pagar pada prediksi rumah),
# ini bekerja pada multiple fitur data
# Lasso (L1) dan Ridge (L2)

# %%
MULTIPLE LINEAR REGRESSION

Konsep multicolinearity:
# ketika dua atau lebih fitur memiliki korelasi yang sangat tinggi, hal ini merupakan masalah
# solusi preventif adalah 
# menggunakan korelasi(hanya 2 fitur) atau VIF atau PCA atau regularization
