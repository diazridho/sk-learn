# %%
from sklearn.datasets import make_blobs

X, _ = make_blobs(n_samples=5000, centers=5, random_state=42)
X

# %%
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

scaler = StandardScaler()
scaler.fit(X)

X_scaled = scaler.transform(X)
X_scaled

plt.scatter(X_scaled[:, 0], X_scaled[:, 1])

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(random_state=42, n_clusters=5)
kmeans.fit(X_scaled)

plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=kmeans.labels_)

# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
X, _ = make_moons(n_samples=1000, random_state=42, noise=0.1)
X
# Out:
# array([[-0.05146968,  0.44419863],
#        [ 1.03201691, -0.41974116],
#        [ 0.86789186, -0.25482711],
#        ...,
#        [ 1.68425911, -0.34822268],
#        [-0.9672013 ,  0.26367208],
#        [ 0.78758971,  0.61660945]], shape=(1000, 2))

# %%
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X)
X_scaled

plt.scatter(X_scaled[:, 0], X_scaled[:, 1])

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=0.2, min_samples=5)
dbscan.fit(X_scaled)

plt.scatter(X[:, 0], X[:, 1], c=dbscan.labels_)

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Contoh 20 data dummy (Umur, Gaji)
data = np.array([[20, 5], [25, 8], [30, 15], [35, 12], [40, 10],
                 [45, 18], [50, 25], [55, 22], [60, 20], [22, 6],
                 [28, 14], [33, 11], [38, 9], [43, 17], [48, 24],
                 [53, 21], [58, 19], [21, 5], [26, 7], [31, 16]])
plt.scatter(data[:, 0], data[:, 1])
