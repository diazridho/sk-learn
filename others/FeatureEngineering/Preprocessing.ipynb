# %% [markdown]
# ### <font color='#ffffff' face='Courier New'>Encoding</font>
# <div style="color:#ffffff; font-family: 'Courier New', monospace; line-height: 1.5;">
# 1.  chi2 <br>
# 2.  Pearson’s r <br>
# 3.  Kendall Tau <br>
# 4.  Spearman’s Rho <br>
# 5.  Mutual Info<br>
# 6.  F-Score <br>
# 7.  Point Biseriasl
# </div>

# %% [markdown]
# ### <font color='#ffffff' face='Courier New'>Binning</font>
# <div style="color:#ffffff; font-family: 'Courier New', monospace; line-height: 1.5;">
# 1.  Equal-width Binning <br>
# 2.  Equal-frequency Binning <br>
# 3.  Entropi-based Binning <br>
# </div>

# %% [markdown]
# ### <font color='#ffffff' face='Courier New'>Scaling</font>

# %% [markdown]
# ### <font color='#ffffff' face='Courier New'>Penanganan Outliers</font>

# %% [markdown]
# ### <font color='#ffffff' face='Courier New'>Oversampling dan Undersampling</font>
# <div style="color:#ffffff; font-family: 'Courier New', monospace; line-height: 1.5;">
# 1.  Random oversampling <br>
# 2.  Smote <br>
# 3.  Random undersampling <br>
# 4.  Centroid based undersampling
#
# </div>
