# %% [markdown]
# ### <font color='#6b6666' face='Courier New'>Handle overfitting</font>
# <div style="color:#ffffff; font-family: 'Courier New', monospace; line-height: 1.5;">
# 1.  Cross validation <br>
# 2.  Earlystopping  <br>
# 3.  Regularization (Lasso(mengurangi fitur), Ridge(membatasi koefisien)) <br>
# 4.  Prunning <br>
# 5.  Data augmentation (memutar/blur/darker gambar) <br>
# 6.  Dropout
#
# </div>
